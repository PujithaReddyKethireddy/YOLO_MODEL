# %% [markdown]
# <a href="https://colab.research.google.com/github/PujithaReddyKethireddy/YOLO_MODEL/blob/main/yolo_bas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Sep  7 13:55:57 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# !pip install torch torchvision ultralytics
# !git clone https://github.com/ultralytics/yolov5.git
# !pip install -r /content/yolov5/requirements.txt
# Out:
# Mounted at /content/gdrive
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Collecting ultralytics
#   Downloading ultralytics-8.3.195-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Downloading ultralytics-8.3.195-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.195 ultralytics-thop-2.0.17
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17564, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 17564 (delta 33), reused 7 (delta 7), pack-reused 17510 (from 3)
# Receiving objects: 100% (17564/17564), 16.69 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (12031/12031), done.
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 5)) (3.1.45)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 8)) (4.12.0.88)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 9)) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 12)) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 13)) (1.16.1)
# Collecting thop>=0.1.1 (from -r /content/yolov5/requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 15)) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 16)) (0.23.0+cu126)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.64 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 18)) (8.3.195)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 42)) (25.0)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/yolov5/requirements.txt (line 43)) (75.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython>=3.1.30->-r /content/yolov5/requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r /content/yolov5/requirements.txt (line 12)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r /content/yolov5/requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r /content/yolov5/requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->-r /content/yolov5/requirements.txt (line 12)) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.4.0)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.64->-r /content/yolov5/requirements.txt (line 18)) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics>=8.2.64->-r /content/yolov5/requirements.txt (line 18)) (2.0.17)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->-r /content/yolov5/requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->-r /content/yolov5/requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r /content/yolov5/requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r /content/yolov5/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->-r /content/yolov5/requirements.txt (line 15)) (3.0.2)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
import os
import xml.etree.ElementTree as ET
from pathlib import Path

def convert_xml_to_yolo(xml_files, output_dir, class_names):
    os.makedirs(output_dir, exist_ok=True)
    for xml_file in xml_files:
        try:
            tree = ET.parse(xml_file)
            root = tree.getroot()
            size = root.find('size')
            if size is None:
                print(f"⚠️ No <size> tag in {xml_file}")
                continue
            width = int(size.find('width').text)
            height = int(size.find('height').text)
            if width == 0 or height == 0:
                print(f"⚠️ Invalid size in {xml_file}")
                continue
            yolo_lines = []
            for obj in root.findall('object'):
                class_name = obj.find('name').text.lower()
                if class_name not in class_names:
                    continue
                class_id = class_names.index(class_name)
                bbox = obj.find('bndbox')
                if bbox is None:
                    continue
                xmin = float(bbox.find('xmin').text)
                ymin = float(bbox.find('ymin').text)
                xmax = float(bbox.find('xmax').text)
                ymax = float(bbox.find('ymax').text)
                x_center = (xmin + xmax) / 2 / width
                y_center = (ymin + ymax) / 2 / height
                bb_width = (xmax - xmin) / width
                bb_height = (ymax - ymin) / height
                yolo_lines.append(f"{class_id} {x_center:.6f} {y_center:.6f} {bb_width:.6f} {bb_height:.6f}")
            if yolo_lines:
                output_file = os.path.join(output_dir, os.path.splitext(os.path.basename(xml_file))[0] + '.txt')
                with open(output_file, 'w') as f:
                    f.write('\n'.join(yolo_lines))
        except Exception as e:
            print(f"⚠️ Error processing {xml_file}: {e}")

class_names = ['missing_hole', 'mouse_bite', 'open_circuit', 'short', 'spur', 'spurious_copper']
annotation_files = []
for root, _, files in os.walk('/content/gdrive/MyDrive/PCB_DATASET/Annotations'):
    annotation_files.extend([os.path.join(root, f) for f in files if f.endswith('.xml')])
convert_xml_to_yolo(annotation_files, '/content/PCB_DATASET/yolo_annotations', class_names)

# Verify conversion
# !ls /content/PCB_DATASET/yolo_annotations | wc -l
# !cat /content/PCB_DATASET/yolo_annotations/01_spur_17.txt
# Out:
# 120
# 4 0.732037 0.388714 0.010547 0.027112
# 4 0.640574 0.482346 0.013514 0.018916
# 4 0.825148 0.386822 0.014173 0.020807

# %%
import os
from pathlib import Path

def analyze_dataset_structure():
    base_path = '/content/gdrive/MyDrive/PCB_DATASET/images'
    all_images = []
    for root, _, files in os.walk(base_path):
        image_files = [f for f in files if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]
        if image_files:
            all_images.extend([os.path.join(root, f) for f in image_files])
            print(f"📁 {root}: {len(image_files)} images")
    annotation_files = [os.path.join('/content/PCB_DATASET/yolo_annotations', f) for f in os.listdir('/content/PCB_DATASET/yolo_annotations') if f.endswith('.txt')]
    print(f"📄 /content/PCB_DATASET/yolo_annotations: {len(annotation_files)} .txt files")
    print(f"📊 Total images: {len(all_images)}, Total annotations: {len(annotation_files)}")
    return all_images, annotation_files

all_images, annotation_files = analyze_dataset_structure()
# Out:
# 📁 /content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper: 20 images
# 📁 /content/gdrive/MyDrive/PCB_DATASET/images/Short: 20 images
# 📁 /content/gdrive/MyDrive/PCB_DATASET/images/Spur: 20 images
# 📁 /content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole: 20 images
# 📁 /content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit: 20 images
# 📁 /content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite: 20 images
# 📄 /content/PCB_DATASET/yolo_annotations: 120 .txt files
# 📊 Total images: 120, Total annotations: 120

# %%
def match_images_with_annotations(all_images, annotation_files):
    matched_pairs = []
    image_lookup = {os.path.splitext(os.path.basename(img))[0]: img for img in all_images}
    annotation_lookup = {os.path.splitext(os.path.basename(ann))[0]: ann for ann in annotation_files}
    for img_name, img_path in image_lookup.items():
        if img_name in annotation_lookup:
            matched_pairs.append((img_path, annotation_lookup[img_name]))
    unmatched_images = [img for img in all_images if os.path.splitext(os.path.basename(img))[0] not in annotation_lookup]
    unmatched_annotations = [ann for ann in annotation_files if os.path.splitext(os.path.basename(ann))[0] not in image_lookup]
    print(f"✅ Matched pairs: {len(matched_pairs)}")
    print(f"⚠️ Unmatched images: {len(unmatched_images)}")
    print(f"⚠️ Unmatched annotations: {len(unmatched_annotations)}")
    if unmatched_images or unmatched_annotations:
        print("Sample unmatched images:", [os.path.basename(img) for img in unmatched_images[:3]])
        print("Sample unmatched annotations:", [os.path.basename(ann) for ann in unmatched_annotations[:3]])
    return matched_pairs

matched_pairs = match_images_with_annotations(all_images, annotation_files)
# Out:
# ✅ Matched pairs: 120
# ⚠️ Unmatched images: 0
# ⚠️ Unmatched annotations: 0

# %%
import shutil
import random
from pathlib import Path

def prepare_yolo_dataset(matched_pairs):
    output_dir = '/content/PCB_DATASET/yolo_final_dataset'
    for split in ['train', 'val', 'test']:
        os.makedirs(os.path.join(output_dir, 'images', split), exist_ok=True)
        os.makedirs(os.path.join(output_dir, 'labels', split), exist_ok=True)
    random.seed(42)
    random.shuffle(matched_pairs)
    n_total = len(matched_pairs)
    n_train = int(0.8 * n_total)  # ~554
    n_val = int(0.15 * n_total)   # ~103
    n_test = n_total - n_train - n_val  # ~36
    splits = {
        'train': matched_pairs[:n_train],
        'val': matched_pairs[n_train:n_train + n_val],
        'test': matched_pairs[n_train + n_val:]
    }
    for split_name, pairs in splits.items():
        for i, (img_path, ann_path) in enumerate(pairs):
            base_name = f"{split_name}_{i:04d}_{os.path.basename(img_path)}"
            shutil.copy2(img_path, os.path.join(output_dir, 'images', split_name, base_name))
            label_name = os.path.splitext(base_name)[0] + '.txt'
            shutil.copy2(ann_path, os.path.join(output_dir, 'labels', split_name, label_name))
        print(f"📁 {split_name}: {len(pairs)} pairs")
    return output_dir

output_dir = prepare_yolo_dataset(matched_pairs)
# Out:
# 📁 train: 96 pairs
# 📁 val: 18 pairs
# 📁 test: 6 pairs

# %%
import yaml

def create_dataset_config(output_dir):
    config = {
        'path': output_dir,
        'train': 'images/train',
        'val': 'images/val',
        'test': 'images/test',
        'nc': 6,
        'names': ['missing_hole', 'mouse_bite', 'open_circuit', 'short', 'spur', 'spurious_copper']
    }
    config_path = os.path.join(output_dir, 'dataset.yaml')
    with open(config_path, 'w') as f:
        yaml.dump(config, f)

    # No augmentation
    hyp = {
        'lr0': 0.01,
        'lrf': 0.1,
        'momentum': 0.937,
        'weight_decay': 0.0005,
        'warmup_epochs': 3.0,
        'warmup_momentum': 0.8,
        'warmup_bias_lr': 0.1,
        'box': 0.05,
        'cls': 0.5,
        'cls_pw': 1.0,
        'obj': 1.0,
        'obj_pw': 1.0,
        'iou_t': 0.2,
        'anchor_t': 4.0,
        'fl_gamma': 0.0,
        'hsv_h': 0.0,    # No hue
        'hsv_s': 0.0,    # No saturation
        'hsv_v': 0.0,    # No value
        'degrees': 0.0,  # No rotation
        'translate': 0.0,# No translation
        'scale': 0.0,    # No scaling
        'shear': 0.0,
        'perspective': 0.0,
        'flipud': 0.0,   # No vertical flip
        'fliplr': 0.0,   # No horizontal flip
        'mosaic': 0.0,   # No mosaic
        'mixup': 0.0,
        'copy_paste': 0.0
    }
    hyp_path = os.path.join(output_dir, 'hyp.no_augmentation.yaml')
    with open(hyp_path, 'w') as f:
        yaml.dump(hyp, f)
    return config_path, hyp_path

output_dir = '/content/PCB_DATASET/yolo_final_dataset'
config_path, hyp_path = create_dataset_config(output_dir)

# %%
import subprocess
import os

def train_yolo_model(config_path, hyp_path):
    os.chdir('/content/yolov5')
    train_cmd = [
        'python', 'train.py',
        '--data', config_path,
        '--hyp', hyp_path,
        '--weights', 'yolov5s.pt',
        '--epochs', '100',
        '--batch-size', '16',
        '--img', '640',
        '--project', 'pcb_defect_detection',
        '--name', 'final_model',
        '--device', '0'
    ]
    subprocess.run(train_cmd, check=True)
    return "/content/yolov5/pcb_defect_detection/final_model"

config_path = '/content/PCB_DATASET/yolo_final_dataset/dataset.yaml'
hyp_path = '/content/PCB_DATASET/yolo_final_dataset/hyp.no_augmentation.yaml'
results_dir = train_yolo_model(config_path, hyp_path)

# %%
results_dir = '/content/yolov5/pcb_defect_detection/final_model'
# !cp {results_dir}/weights/best.pt /content/gdrive/MyDrive/YOLOv5_model.pt
# !zip -r /content/results.zip {results_dir}
# !cp /content/results.zip /content/gdrive/MyDrive/results.zip
# Out:
#   adding: content/yolov5/pcb_defect_detection/final_model/ (stored 0%)
#   adding: content/yolov5/pcb_defect_detection/final_model/opt.yaml (deflated 50%)
#   adding: content/yolov5/pcb_defect_detection/final_model/val_batch0_pred.jpg (deflated 18%)
#   adding: content/yolov5/pcb_defect_detection/final_model/hyp.yaml (deflated 46%)
#   adding: content/yolov5/pcb_defect_detection/final_model/P_curve.png (deflated 9%)
#   adding: content/yolov5/pcb_defect_detection/final_model/F1_curve.png (deflated 7%)
#   adding: content/yolov5/pcb_defect_detection/final_model/labels.jpg (deflated 37%)
#   adding: content/yolov5/pcb_defect_detection/final_model/confusion_matrix.png (deflated 24%)
#   adding: content/yolov5/pcb_defect_detection/final_model/train_batch2.jpg (deflated 23%)
#   adding: content/yolov5/pcb_defect_detection/final_model/train_batch1.jpg (deflated 23%)
#   adding: content/yolov5/pcb_defect_detection/final_model/labels_correlogram.jpg (deflated 43%)
#   adding: content/yolov5/pcb_defect_detection/final_model/R_curve.png (deflated 10%)
#   adding: content/yolov5/pcb_defect_detection/final_model/events.out.tfevents.1757253758.59390ba68b0b.2236.0 (deflated 28%)
#   adding: content/yolov5/pcb_defect_detection/final_model/val_batch0_labels.jpg (deflated 16%)
#   adding: content/yolov5/pcb_defect_detection/final_model/train_batch0.jpg (deflated 23%)
#   adding: content/yolov5/pcb_defect_detection/final_model/results.csv (deflated 84%)
#   adding: content/yolov5/pcb_defect_detection/final_model/results.png (deflated 6%)
#   adding: content/yolov5/pcb_defect_detection/final_model/PR_curve.png (deflated 16%)
#   adding: content/yolov5/pcb_defect_detection/final_model/weights/ (stored 0%)
#   adding: content/yolov5/pcb_defect_detection/final_model/weights/best.pt (deflated 8%)
#   adding: content/yolov5/pcb_defect_detection/final_model/weights/last.pt (deflated 8%)

# %%
# !python /content/yolov5/detect.py --weights /content/gdrive/MyDrive/YOLOv5_model.pt --source /content/PCB_DATASET/yolo_final_dataset/images/test --project /content/results --name test_inference
# !cp -r /content/results/test_inference /content/gdrive/MyDrive/results/test_inference
# !python /content/yolov5/detect.py --weights /content/gdrive/MyDrive/YOLOv5_model.pt --source /content/gdrive/MyDrive/PCB_DATASET/PCB_USED --project /content/results --name pcb_used_inference
# !cp -r /content/results/pcb_used_inference /content/gdrive/MyDrive/results/pcb_used_inference
# Out:
# detect: weights=['/content/gdrive/MyDrive/YOLOv5_model.pt'], source=/content/PCB_DATASET/yolo_final_dataset/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/results, name=test_inference, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/6 /content/PCB_DATASET/yolo_final_dataset/images/test/test_0000_01_short_17.jpg: 352x640 4 shorts, 33.2ms
# image 2/6 /content/PCB_DATASET/yolo_final_dataset/images/test/test_0001_01_short_12.jpg: 352x640 5 shorts, 7.5ms
# image 3/6 /content/PCB_DATASET/yolo_final_dataset/images/test/test_0002_01_open_circuit_17.jpg: 352x640 1 spur, 7.5ms
# image 4/6 /content/PCB_DATASET/yolo_final_dataset/images/test/test_0003_01_spurious_copper_04.jpg: 352x640 2 spurious_coppers, 7.5ms
# image 5/6 /content/PCB_DATASET/yolo_final_dataset/images/test/test_0004_01_spurious_copper_11.jpg: 352x640 (no detections), 7.5ms
# image 6/6 /content/PCB_DATASET/yolo_final_dataset/images/test/test_0005_01_open_circuit_02.jpg: 352x640 (no detections), 7.5ms
# Speed: 0.6ms pre-process, 11.8ms inference, 24.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/results/test_inference
# cp: cannot create directory '/content/gdrive/MyDrive/results/test_inference': No such file or directory
# detect: weights=['/content/gdrive/MyDrive/YOLOv5_model.pt'], source=/content/gdrive/MyDrive/PCB_DATASET/PCB_USED, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/results, name=pcb_used_inference, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-430-g459d8bf0 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/01.JPG: 352x640 (no detections), 35.5ms
# image 2/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/04.JPG: 544x640 11 missing_holes, 6 mouse_bites, 3 open_circuits, 30 shorts, 3 spurious_coppers, 50.6ms
# image 3/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/05.JPG: 544x640 1 mouse_bite, 2 open_circuits, 3 shorts, 4 spurious_coppers, 11.2ms
# image 4/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/06.JPG: 544x640 5 missing_holes, 9 mouse_bites, 7 open_circuits, 26 shorts, 1 spur, 19 spurious_coppers, 11.2ms
# image 5/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/07.JPG: 448x640 1 open_circuit, 1 short, 1 spurious_copper, 33.1ms
# image 6/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/08.JPG: 512x640 19 missing_holes, 1 mouse_bite, 2 open_circuits, 69 shorts, 17 spurious_coppers, 31.7ms
# image 7/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/09.JPG: 512x640 10 missing_holes, 3 open_circuits, 28 shorts, 1 spur, 4 spurious_coppers, 9.0ms
# image 8/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/10.JPG: 576x640 3 spurious_coppers, 32.3ms
# image 9/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/11.JPG: 640x640 2 open_circuits, 1 spurious_copper, 11.6ms
# image 10/10 /content/gdrive/MyDrive/PCB_DATASET/PCB_USED/12.JPG: 640x640 1 mouse_bite, 4 open_circuits, 15 shorts, 3 spurious_coppers, 11.5ms
# Speed: 0.6ms pre-process, 23.8ms inference, 11.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/results/pcb_used_inference
# cp: cannot create directory '/content/gdrive/MyDrive/results/pcb_used_inference': No such file or directory

# %%
# !zip -r /content/PCB_DATASET.zip /content/gdrive/MyDrive/PCB_DATASET/images /content/gdrive/MyDrive/PCB_DATASET/Annotations
# !cp /content/PCB_DATASET.zip /content/gdrive/MyDrive/PCB_DATASET.zip
# Out:
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_12.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_10.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_13.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_04.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_08.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_06.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_09.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_01.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_20.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_18.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_05.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_16.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_19.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_07.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_11.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_17.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_15.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_03.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_02.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spurious_copper/01_spurious_copper_14.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_13.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_01.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_05.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_07.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_15.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_02.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_14.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_08.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_09.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_06.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_11.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_17.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_18.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_03.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_10.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_12.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_19.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_16.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_04.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Short/01_short_20.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_02.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_03.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_04.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_01.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_05.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_06.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_16.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_11.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_17.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_19.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_07.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_15.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_08.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_09.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_18.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_12.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_20.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_13.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_10.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Spur/01_spur_14.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_02.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_09.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_01.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_10.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_05.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_17.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_19.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_03.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_06.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_15.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_12.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_20.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_16.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_14.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_08.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_18.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_07.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_13.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_11.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Missing_hole/01_missing_hole_04.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_04.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_02.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_08.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_01.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_13.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_19.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_05.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_14.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_11.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_15.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_09.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_12.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_07.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_03.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_17.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_18.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_06.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_20.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_16.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Open_circuit/01_open_circuit_10.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_17.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_08.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_10.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_20.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_14.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_12.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_18.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_19.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_04.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_15.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_13.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_07.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_16.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_02.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_03.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_01.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_11.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_09.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_06.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/images/Mouse_bite/01_mouse_bite_05.jpg (deflated 1%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_02.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_03.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_04.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_01.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_09.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_19.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_08.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_10.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_12.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_20.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_11.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_06.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_05.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_17.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_14.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_07.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_18.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_16.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_13.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spurious_copper/01_spurious_copper_15.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_01.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_12.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_03.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_10.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_19.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_08.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_11.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_09.xml (deflated 77%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_15.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_07.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_13.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_16.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_02.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_18.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_14.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_05.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_20.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_06.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_17.xml (deflated 71%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Short/01_short_04.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_15.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_04.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_17.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_18.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_19.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_09.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_14.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_06.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_03.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_02.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_01.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_16.xml (deflated 60%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_11.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_05.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_10.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_20.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_12.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_08.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_13.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Open_circuit/01_open_circuit_07.xml (deflated 68%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_03.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_11.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_06.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_05.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_02.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_08.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_12.xml (deflated 59%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_14.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_09.xml (deflated 59%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_20.xml (deflated 59%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_18.xml (deflated 59%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_19.xml (deflated 60%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_17.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_04.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_01.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_15.xml (deflated 59%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_13.xml (deflated 59%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_07.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_16.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Spur/01_spur_10.xml (deflated 66%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_06.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_20.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_12.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_05.xml (deflated 72%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_10.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_02.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_01.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_18.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_16.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_03.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_09.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_15.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_14.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_07.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_08.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_04.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_19.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_13.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_11.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Missing_hole/01_missing_hole_17.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/ (stored 0%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_09.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_18.xml (deflated 48%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_12.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_15.xml (deflated 60%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_02.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_03.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_07.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_10.xml (deflated 60%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_13.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_04.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_05.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_08.xml (deflated 60%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_01.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_11.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_17.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_06.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_14.xml (deflated 60%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_20.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_16.xml (deflated 67%)
#   adding: content/gdrive/MyDrive/PCB_DATASET/Annotations/Mouse_bite/01_mouse_bite_19.xml (deflated 60%)
